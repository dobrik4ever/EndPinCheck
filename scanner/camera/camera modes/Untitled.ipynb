# %%
import pandas as pd

# %%
df = pd.read_excel('BRIO.xlsx')
# df.set_index('Quality')
df
# Out:
#     Quality  Aspect ratio x  Aspect ratio y  resx  resy  fps
# 0      2160              16               9  3840  2160   30
# 1      1440              16               9  2560  1440   30
# 2      1080              16               9  1920  1080   60
# 3       720              16               9  1280   720   60
# 4       720              16               9  1280   720   30
# 5       576              16               9  1024   576   30
# 6       540              16               9   960   540   30
# 7       360              16               9   640   360   30
# 8       270              16               9   480   270   30
# 9       180              16               9   320   180   30
# 10      600               4               3   800   600   30
# 11      480               4               3   640   480   60
# 12      480               4               3   640   480   30
# 13      240               4               3   320   240   30
# ...

# %%
a = df['Quality'].duplicated()
df[a]
a = df['Quality'].drop_duplicates()
list(a)
# Out:
# [2160,
#  1440,
#  1080,
#  720,
#  576,
#  540,
#  360,
#  270,
#  180,
#  600,
#  480,
#  240,
#  120,
#  440,
#  340,
#  288,
#  144]

# %%
kek =[]
for i in a:
    kek.append(df.loc[df['Quality'] == i])
    
# print(kek)

# %%
# b = df['Quality'].duplicated()
# df[b]
b = df['fps'].drop_duplicates().astype(str)
list(b)
# Out:
# ['30', '60']
